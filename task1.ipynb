# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm,shapiro
from statsmodels.graphics.gofplots import qqplot
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d89b62df-74ca-4eae-88bb-81632c382a90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d89b62df-74ca-4eae-88bb-81632c382a90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('StudentPerformanceFactors.csv')
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
# Histogram
plt.figure(figsize=(8, 6))
plt.hist(df['Hours_Studied'], bins=30, density=True)
plt.title('Histogram of Hours Studied')
plt.xlabel('Hours_Studied')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
plt.hist(df['Attendance'], bins=30, density=True)
plt.title('Histogram of Hours attendance')
plt.xlabel('Attendance')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
plt.hist(df['Sleep_Hours'], bins=30, density=True)
plt.hist(df['Previous_Scores'], bins=30, density=True)
plt.title('Histogram ')
plt.xlabel('Sleep_hours')
plt.ylabel('Previous_Scores')
plt.grid(True)
plt.show()

# %%
# Histogram
plt.figure(figsize=(8, 6))
plt.hist(df['Sleep_Hours'], bins=30, density=True)
plt.title('Histogram for Sleep_Hours')
plt.xlabel('Sleep_hours')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
